# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from pandas import Series,DataFrame
pd.options.display.max_rows = 9999
Data=pd.read_csv('tips.csv')
Data
# Out:
#      total_bill      tip  gender smoker   day    time  size
# 0       2125.50   360.79    Male     No  Thur   Lunch     1
# 1       2727.18   259.42  Female     No   Sun  Dinner     5
# 2       1066.02   274.68  Female    Yes  Thur  Dinner     4
# 3       3493.45   337.90  Female     No   Sun  Dinner     1
# 4       3470.56   567.89    Male    Yes   Sun   Lunch     6
# 5       2411.08   296.48  Female    Yes  Thur   Lunch     2
# 6       4607.43   374.96  Female     No  Thur  Dinner     4
# 7       1165.21   700.87  Female     No   Mon  Dinner     2
# 8       2895.04   347.71    Male     No   Sat  Dinner     5
# 9       2622.54   253.97    Male    Yes  Thur   Lunch     6
# 10      2572.40   499.22    Male     No   Wed   Lunch     2
# 11      1602.30   336.81    Male    Yes   Wed   Lunch     1
# 12      1888.97   451.26  Female     No  Tues   Lunch     3
# 13      2643.25   541.73    Male     No   Sun  Dinner     6
# 14      1899.87   213.64    Male    Yes   Fri  Dinner     4
# ...

# %%
Data.drop_duplicates()
# Out:
#      total_bill      tip  gender smoker   day    time  size
# 0       2125.50   360.79    Male     No  Thur   Lunch     1
# 1       2727.18   259.42  Female     No   Sun  Dinner     5
# 2       1066.02   274.68  Female    Yes  Thur  Dinner     4
# 3       3493.45   337.90  Female     No   Sun  Dinner     1
# 4       3470.56   567.89    Male    Yes   Sun   Lunch     6
# 5       2411.08   296.48  Female    Yes  Thur   Lunch     2
# 6       4607.43   374.96  Female     No  Thur  Dinner     4
# 7       1165.21   700.87  Female     No   Mon  Dinner     2
# 8       2895.04   347.71    Male     No   Sat  Dinner     5
# 9       2622.54   253.97    Male    Yes  Thur   Lunch     6
# 10      2572.40   499.22    Male     No   Wed   Lunch     2
# 11      1602.30   336.81    Male    Yes   Wed   Lunch     1
# 12      1888.97   451.26  Female     No  Tues   Lunch     3
# 13      2643.25   541.73    Male     No   Sun  Dinner     6
# 14      1899.87   213.64    Male    Yes   Fri  Dinner     4
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  744 non-null    float64
#  1   tip         744 non-null    float64
#  2   gender      744 non-null    object
#  3   smoker      744 non-null    object
#  4   day         744 non-null    object
#  5   time        744 non-null    object
#  6   size        744 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 40.8+ KB

# %%
Data.describe()
# Out:
#         total_bill          tip        size
# count   744.000000   744.000000  744.000000
# mean   2165.006640   325.948091    3.180108
# std     954.248806   148.778225    1.532890
# min      44.690000     0.000000    1.000000
# 25%    1499.022500   218.000000    2.000000
# 50%    2102.610000   320.460000    3.000000
# 75%    2743.802500   415.562500    4.000000
# max    5538.290000  1090.000000    6.000000

# %%
Data.columns
# Out:
# Index(['total_bill', 'tip', 'gender', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
Data.head()
# Out:
#    total_bill     tip  gender smoker   day    time  size
# 0     2125.50  360.79    Male     No  Thur   Lunch     1
# 1     2727.18  259.42  Female     No   Sun  Dinner     5
# 2     1066.02  274.68  Female    Yes  Thur  Dinner     4
# 3     3493.45  337.90  Female     No   Sun  Dinner     1
# 4     3470.56  567.89    Male    Yes   Sun   Lunch     6

# %%
Data.tail()
# Out:
#      total_bill     tip  gender smoker   day    time  size
# 739     3164.27  645.28    Male     No   Sat  Dinner     3
# 740     2962.62  218.00  Female    Yes   Sat  Dinner     2
# 741     2471.03  218.00    Male    Yes   Sat  Dinner     2
# 742     1942.38  190.75    Male     No   Sat  Dinner     2
# 743     2047.02  327.00  Female     No  Thur  Dinner     2

# %%
Data.isnull()
# Out:
#      total_bill    tip  gender  smoker    day   time   size
# 0         False  False   False   False  False  False  False
# 1         False  False   False   False  False  False  False
# 2         False  False   False   False  False  False  False
# 3         False  False   False   False  False  False  False
# 4         False  False   False   False  False  False  False
# ..          ...    ...     ...     ...    ...    ...    ...
# 739       False  False   False   False  False  False  False
# 740       False  False   False   False  False  False  False
# 741       False  False   False   False  False  False  False
# 742       False  False   False   False  False  False  False
# 743       False  False   False   False  False  False  False
#
# [744 rows x 7 columns]

# %%
Data.shape
# Out:
# (744, 7)

# %%
Data.size
# Out:
# 5208

# %%
Data['tip'].median
# Out:
# <bound method Series.median of 0      360.79
# 1      259.42
# 2      274.68
# 3      337.90
# 4      567.89
#         ...
# 739    645.28
# 740    218.00
# 741    218.00
# 742    190.75
# 743    327.00
# Name: tip, Length: 744, dtype: float64>

# %%
Data['tip'].mode
# Out:
# <bound method Series.mode of 0      360.79
# 1      259.42
# 2      274.68
# 3      337.90
# 4      567.89
#         ...
# 739    645.28
# 740    218.00
# 741    218.00
# 742    190.75
# 743    327.00
# Name: tip, Length: 744, dtype: float64>

# %%
Data['total_bill'].mode
# Out:
# <bound method Series.mode of 0      2125.50
# 1      2727.18
# 2      1066.02
# 3      3493.45
# 4      3470.56
#         ...
# 739    3164.27
# 740    2962.62
# 741    2471.03
# 742    1942.38
# 743    2047.02
# Name: total_bill, Length: 744, dtype: float64>

# %%
Data.groupby('total_bill').tip.agg(['mean','max','median','min'])
# Out:
#                 mean      max    median      min
# total_bill
# 44.69        134.070   134.07   134.070   134.07
# 58.86        333.540   333.54   333.540   333.54
# 94.83        300.295   385.86   300.295   214.73
# 97.01        385.860   385.86   385.860   385.86
# 118.81       218.000   218.00   218.000   218.00
# ...              ...      ...       ...      ...
# 5250.53      545.000   545.00   545.000   545.00
# 5261.43      733.570   733.57   733.570   733.57
# 5267.97      981.000   981.00   981.000   981.00
# 5279.96      234.350   234.35   234.350   234.35
# 5538.29     1090.000  1090.00  1090.000  1090.00
#
# [636 rows x 4 columns]

# %%
Data.groupby('gender').tip.agg(['mean','max','median','min'])
# Out:
#               mean      max  median   min
# gender
# Female  325.041254   737.93  320.46  0.00
# Male    326.690856  1090.00  320.46  1.09

# %%
Data.groupby('smoker').tip.agg(['mean','max','median','min'])
# Out:
#               mean     max   median   min
# smoker
# No      330.576734   981.0  323.185  0.00
# Yes     320.623815  1090.0  316.100  1.09

# %%
Data.groupby('day').tip.agg(['mean','max','median','min'])
# Out:
#             mean      max   median    min
# day
# Fri   291.595696   602.77  292.120   0.00
# Mon   321.986000   700.87  301.930   1.09
# Sat   329.107333  1090.00  313.920   4.36
# Sun   342.548071   708.50  336.810  15.26
# Thur  325.527687   730.30  301.930   1.09
# Tues  336.027436   768.45  342.805  54.50
# Wed   318.220274   606.04  328.090   4.36

# %%
Data.groupby('time').tip.agg(['mean','max','median','min'])
# Out:
#               mean     max  median   min
# time
# Dinner  333.210703  1090.0  327.00  1.09
# Lunch   316.165331   730.3  300.84  0.00

# %%
Data.groupby('size').tip.agg(['mean','max','median','min'])
# Out:
#             mean      max  median    min
# size
# 1     301.372024   704.14  324.82   4.36
# 2     304.738136   737.93  281.22   1.09
# 3     346.365940  1090.00  334.63  14.17
# 4     353.597717   981.00  327.00   4.36
# 5     323.407037   768.45  311.74   1.09
# 6     338.582892   730.30  330.27   0.00

# %%
sns.set(style = 'darkgrid')

# %%
print(plt.style.available)
plt.style.use('seaborn-v0_8-darkgrid')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
sns.relplot(x = 'gender', y = 'tip', data=Data)

# %%
Data.plot.scatter(x='time', y='total_bill', s=30, c='blue')
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
# Comments
# This explains the count in the data. 
# There appeared to be a higher level of patronage from the male gender compared to female.


sns.countplot(x='gender',data=Data)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(x='smoker',data=Data)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
Data=Data.set_index('day')

# %%
Data.head()
# Out:
#       total_bill     tip  gender smoker    time  size
# day
# Thur     2125.50  360.79    Male     No   Lunch     1
# Sun      2727.18  259.42  Female     No  Dinner     5
# Thur     1066.02  274.68  Female    Yes  Dinner     4
# Sun      3493.45  337.90  Female     No  Dinner     1
# Sun      3470.56  567.89    Male    Yes   Lunch     6

# %%
Data=Data.set_index('gender')

# %%
Data.head()
# Out:
#         total_bill     tip smoker    time  size
# gender
# Male       2125.50  360.79     No   Lunch     1
# Female     2727.18  259.42     No  Dinner     5
# Female     1066.02  274.68    Yes  Dinner     4
# Female     3493.45  337.90     No  Dinner     1
# Male       3470.56  567.89    Yes   Lunch     6

# %%
Data.sort_index()
# Out:
#         total_bill      tip smoker    time  size
# gender
# Female     1655.71   325.91     No  Dinner     3
# Female     1915.13   341.17    Yes  Dinner     1
# Female     2235.59   248.52    Yes  Dinner     4
# Female     2089.53   211.46     No   Lunch     5
# Female     1439.89   299.75    Yes  Dinner     2
# Female     1480.22   552.63    Yes   Lunch     2
# Female     3643.87   432.73     No  Dinner     3
# Female     1953.28   116.63     No  Dinner     5
# Female      445.81   554.81    Yes  Dinner     5
# Female      214.73   457.80     No   Lunch     2
# Female      996.26   398.94     No   Lunch     3
# Female      260.51   336.81    Yes  Dinner     4
# Female     2536.43   324.82    Yes  Dinner     4
# Female     2170.19   294.30    Yes   Lunch     4
# Female     1791.96   336.81     No  Dinner     2
# Female     2004.51   272.50    Yes  Dinner     5
# Female     2451.41   292.12     No   Lunch     1
# Female     1966.36   625.66     No  Dinner     2
# ...
